# %%
import sys
sys.path.append("/home1/09528/sumbarger/simulation_analysis_tools/") 
import gizmo_analysis as gizmo 
import utilities as ut
#from fof_analysis import fof
import numpy as np
import pandas as pd
from matplotlib import pylab as plt
from matplotlib import rc #to use Latex math symbols like 'phi'
import matplotlib.colors as colors
import matplotlib.gridspec as gridspec
import seaborn as sns
from astropy.table import Table
from astropy.io import ascii
import pickle

# %%
# Function to read pickle files for 640
def data(pkl_path):
    data_dict = {}
    
    filenames = [
        #'m12i_mhdcv_rl_640_whole20_indices_n20_z15_T1e4_ll20pc.pkl',
        'm12i_mhdcv_rl_640_whole20_xcm_n20_T1e4_z15_ll20pc.pkl',
        'm12i_mhdcv_rl_640_whole20_ycm_n20_T1e4_z15_ll20pc.pkl',
        'm12i_mhdcv_rl_640_whole20_zcm_n20_T1e4_z15_ll20pc.pkl',
        'm12i_mhdcv_rl_640_whole20_m_n20_T1e4_z15_ll20pc.pkl',
        'm12i_mhdcv_rl_640_whole20_r90_n20_T1e4_z15_ll20pc.pkl',
        'm12i_mhdcv_rl_640_whole20_r50_n20_T1e4_z15_ll20pc.pkl'
        
    ]
    
    keys = ['xcm', 'ycm', 'zcm', 'mass', 'r50', 'r90', ]
    
    for i, filename in enumerate(filenames):
        with open(f"{pkl_path}/{filename}", 'rb') as handle:
            data_dict[keys[i]] = pickle.load(handle)
    
    return data_dict

m12i_640 = data('/home1/09528/sumbarger/GMC_project/m12i_cloud_1Myr/snapshot_640')

# Now, "m12i_640_data" is a dictionary where each key represents a type of data, and the value is the loaded data.
#print(m12i_640.keys())

#converts it into a dataframe
df = pd.DataFrame(m12i_640)
df['cloud_number'] = range(1, 1664)
df = df.reset_index(drop=True)
df = df[['cloud_number', 'xcm', 'ycm', 'zcm', 'mass', 'r50', 'r90']]
df

#converts it into a csv file
#df.to_csv('m12i_640_data.csv', index=False)

#converts it into a txt file
#df.to_csv('m12i_640_data.txt', sep='\t', index=False)
# Out:
#       cloud_number        xcm        ycm       zcm          mass       r50  \
# 0                1  -3.887161   5.905026 -0.161226  3.935615e+07  0.411421
# 1                2  12.854999  -3.891181  0.217690  1.986788e+07  0.272022
# 2                3  -4.338049  -1.542130  0.037710  2.127662e+07  0.311038
# 3                4  -6.149781   2.510938 -0.144289  1.491134e+07  0.210329
# 4                5  -3.990502 -12.271435 -0.028869  1.360364e+07  0.208969
# ...            ...        ...        ...       ...           ...       ...
# 1658          1659  11.461170  -1.705598 -0.342353  2.262157e+05  0.037893
# 1659          1660  -6.236484  -7.910777  0.415803  2.135150e+05  0.041296
# 1660          1661  -6.010402  -1.779883 -0.329083  2.298325e+05  0.043397
# 1661          1662  -5.682501  -2.114396 -0.231419  2.253042e+05  0.045401
# 1662          1663  -4.122827  -1.570210  0.127768  2.262182e+05  0.031093
#
#            r90
# 0     0.242353
# 1     0.158377
# 2     0.189292
# ...

# %%
def data(pkl_path):
    data_dict = {}
    
    filenames = [
        'm12i_mhdcv_rl_640_whole20_indices_n20_z15_T1e4_ll20pc.pkl'
    ]
    
    keys = ['values']
    
    for i, filename in enumerate(filenames):
        with open(f"{pkl_path}/{filename}", 'rb') as handle:
            data_dict[keys[i]] = pickle.load(handle)
    
    return data_dict

m12i_640_ind = data('/home1/09528/sumbarger/GMC_project/m12i_cloud_1Myr/snapshot_640')

# Now, "m12i_640_data" is a dictionary where each key represents a type of data, and the value is the loaded data.
print(m12i_640_ind.keys())
df_ind = pd.DataFrame(m12i_640_ind)
df_ind.keys()

nind = len(df_ind['values'])
print(nind)
for i in range(nind):
    rowi = df_ind['values'][i] #locations in an array
    #print(len(rowi))
# Out:
# dict_keys(['values'])
# 1663

# %%
for n in range(580,601):

    path=r'C:/Users/joeyz/OneDrive/Desktop/School Stuff/UCM Stuff/Research/Stampede_Data/Output_m12i_r7100/'
    load_pickles = path
    filename = 'm12i_rl_'+str(n)+'_whole20_indices_n20_z15_T1e4_ll20pc.pkl'
    file_open = open(load_pickles+filename, 'rb')
    m12i_indices = pickle.load(file_open)

    path=r'C:/Users/joeyz/OneDrive/Desktop/School Stuff/UCM Stuff/Research/Stampede_Data/Output_m12i_r7100/'
    load_pickles = path
    filename = 'm12i_rl_'+str(n)+'_whole20_m_n20_T1e4_z15_ll20pc.pkl'
    file_open = open(load_pickles+filename, 'rb')
    m12i_m = pickle.load(file_open)

    path=r'C:/Users/joeyz/OneDrive/Desktop/School Stuff/UCM Stuff/Research/Stampede_Data/Output_m12i_r7100/'
    load_pickles = path
    filename = 'm12i_rl_'+str(n)+'_whole20_r50_n20_T1e4_z15_ll20pc.pkl'
    file_open = open(load_pickles+filename, 'rb')
    m12i_r50 = pickle.load(file_open)

    path=r'C:/Users/joeyz/OneDrive/Desktop/School Stuff/UCM Stuff/Research/Stampede_Data/Output_m12i_r7100/'
    load_pickles = path
    filename = 'm12i_rl_'+str(n)+'_whole20_r90_n20_T1e4_z15_ll20pc.pkl'
    file_open = open(load_pickles+filename, 'rb')
    m12i_r90 = pickle.load(file_open)

    path=r'C:/Users/joeyz/OneDrive/Desktop/School Stuff/UCM Stuff/Research/Stampede_Data/Output_m12i_r7100/'
    load_pickles = path
    filename = 'm12i_rl_'+str(n)+'_whole20_xcm_n20_T1e4_z15_ll20pc.pkl'
    file_open = open(load_pickles+filename, 'rb')
    m12i_xcm = pickle.load(file_open)

    path=r'C:/Users/joeyz/OneDrive/Desktop/School Stuff/UCM Stuff/Research/Stampede_Data/Output_m12i_r7100/'
    load_pickles = path
    filename = 'm12i_rl_'+str(n)+'_whole20_ycm_n20_T1e4_z15_ll20pc.pkl'
    file_open = open(load_pickles+filename, 'rb')
    m12i_ycm = pickle.load(file_open)

    path=r'C:/Users/joeyz/OneDrive/Desktop/School Stuff/UCM Stuff/Research/Stampede_Data/Output_m12i_r7100/'
    load_pickles = path
    filename = 'm12i_rl_'+str(n)+'_whole20_zcm_n20_T1e4_z15_ll20pc.pkl'
    file_open = open(load_pickles+filename, 'rb')
    m12i_zcm = pickle.load(file_open)
    
    # Combine lists into a DataFrame
    df = pd.DataFrame({'m12i_indices': m12i_indices, 'm12i_m': m12i_m, 'm12i_r50': m12i_r50,'m12i_r90': m12i_r90,'m12i_xcm': m12i_xcm,'m12i_ycm': m12i_ycm,'m12i_zcm': m12i_zcm})

    # Specify the path to save the CSV file
    csv_path = 'C:/Users/joeyz/OneDrive/Desktop/School Stuff/UCM Stuff/Research/Stampede_Data/Output_m12i_r7100/m12i_r7100_csv_files/m12i_r7100_'+str(n)+'.csv'

    # Save DataFrame to CSV
    df.to_csv(csv_path, index=False)
